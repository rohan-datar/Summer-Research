# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = np.loadtxt("psi.dat")

x1 = data1[:,0]
psi1 = data1[:,1]

# data = open("psi.dat", "r")

# x = []
# psi = []
# i = 0

# for l in data.readlines():
#     point = l.split()
#     #print(point)
#     x.append(point[0])
#     psi.append(point[1])
#     i +=1

#print(x)
#print(psi)
plt.plot(x1, psi1)

# %%
import matplotlib.pyplot as plt
import numpy as np

data2 = np.loadtxt("myPsi.dat")

x2 = data2[:,0]
psi2 = data2[:,1]

plt.plot(x2, psi2)

# %%
x = np.arange(-5, 5, 0.05)
y = np.cos(x)
plt.plot(x,y)
# Out:
# [ 0.28366219  0.23538144  0.18651237  0.13717711  0.08749898  0.03760215
#  -0.01238866 -0.06234851 -0.11215253 -0.16167622 -0.2107958  -0.2593885
#  -0.30733287 -0.35450907 -0.40079917 -0.44608749 -0.49026082 -0.53320876
#  -0.57482395 -0.61500238 -0.65364362 -0.6906511  -0.7259323  -0.75939906
#  -0.79096771 -0.82055936 -0.84810003 -0.8735209  -0.89675842 -0.91775451
#  -0.93645669 -0.95281821 -0.96679819 -0.97836168 -0.98747977 -0.99412968
#  -0.99829478 -0.99996466 -0.99913515 -0.99580832 -0.9899925  -0.9817022
#  -0.97095817 -0.95778724 -0.94222234 -0.92430238 -0.90407214 -0.8815822
#  -0.85688875 -0.83005354 -0.80114362 -0.77023125 -0.73739372 -0.70271308
#  -0.66627602 -0.62817362 -0.58850112 -0.54735767 -0.5048461  -0.46107269
#  -0.41614684 -0.37018083 -0.32328957 -0.27559025 -0.22720209 -0.17824606
#  -0.12884449 -0.07912089 -0.02919952  0.02079483  0.0707372   0.12050277
#   0.16996714  0.21900669  0.26749883  0.31532236  0.36235775  0.40848744
# ...

# %%
plt.plot(x1, np.abs(psi1 - psi2))
plt.yscale('log')
