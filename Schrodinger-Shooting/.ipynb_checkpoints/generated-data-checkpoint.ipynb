# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = np.loadtxt("psi.dat")

x1 = data1[:,0]
psi1 = data1[:,1]


plt.plot(x1, psi1)

# %%
import matplotlib.pyplot as plt
import numpy as np

data2 = np.loadtxt("myPsi.dat")

x2 = data2[:,0]
psi2 = data2[:,1]

plt.plot(x2, psi2)

# %%
x = np.arange(-5.05, 5, 0.05)
y = np.cos((np.pi*x)/2)
plt.plot(x,y)

# %%
y1 = np.abs(psi2 - y)
#print(y1)
plt.plot(x1, y1)
#plt.yscale('log')
